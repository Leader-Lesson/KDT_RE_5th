# %% [markdown]
# # 04. Autograd(자동미분)
# - Pytorch는 Tensor의 모든 연산에 대해 자동미분이 가능함!
# - 자동미분은 역전파에 활용됨
# - `requires_grad` : Tensor의 속성으로, True로 설정해야 자동미분이 가능
# - `tensor.backward()` : 미분 실행
# - `tensor.grad` : 미분값을 확인할 수 있는 속성

# %%
import torch

# %%
x = torch.tensor([1.], requires_grad=True)
y = x ** 2
print(y)
print("미분전:", x.grad)

# backward()는 기본적으로 한 번만 쓰고 그래프를 버립니다.
# 같은 그래프로 두 번째 역전파가 필요하면 y.backward(retain_graph=True)를 사용해야 합니다.
y.backward(retain_graph=True)  # retain_graph=True 추가
print("미분후:", x.grad)

# x.grad.zero_() : 초기화 (초기화 하지 않으면 기본은 누적됨)
z = 3 * y
print(z)

z.backward()
print("z미분후:", x.grad)
# Out:
# tensor([1.], grad_fn=<PowBackward0>)
# 미분전: None
# 미분후: tensor([2.])
# tensor([3.], grad_fn=<MulBackward0>)
# z미분후: tensor([8.])

# %%
# 체인룰 
x = torch.tensor([1.], requires_grad=True)
a = x ** 2
b = a + 1
c = b ** 2
c.backward()
print(x.grad)
# 이 텐서를 계산 그래프에서 분리한다
result = x.grad.detach()
print(result.requires_grad)
print(result.item())
# Out:
# tensor([8.])
# False
# 8.0

# %%
# 다변수 함수 미분
x = torch.tensor([1.], requires_grad=True)
y = torch.tensor([3.], requires_grad=True)
z = 2*(x**2) + y**2
print(z)
z.backward()
print(x.grad)
print(y.grad)
# Out:
# tensor([11.], grad_fn=<AddBackward0>)
# tensor([4.])
# tensor([6.])

# %%
# with torch.no_grad():
# grad_fn을 계산하고 싶지 않을때 사용
# => 모델 훈련 후 test data를 가지고 평가할 때 사용

x = torch.tensor([1.], requires_grad=True)

with torch.no_grad():
  y = x**2
  print(x.requires_grad)
  print(y)
  
print(x.requires_grad)
# y = x**2
y.backward() # with 구문 안쪽의 y로 미분 시도시 에러
# Out:
# True
# tensor([1.])
# True
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[11], line 14
#      12 print(x.requires_grad)
#      13 # y = x**2
# ---> 14 y.backward() # with 구문 안쪽의 y로 미분 시도시 에러
#
# File c:\Users\SPREATICS1\Desktop\수업코드 git\KDT_RE_5th\.venv\Lib\site-packages\torch\_tensor.py:630, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     620 if has_torch_function_unary(self):
#     621     return handle_torch_function(
#     622         Tensor.backward,
#     623         (self,),
#    (...)    628         inputs=inputs,
#     629     )
# --> 630 torch.autograd.backward(
#     631     self, gradient, retain_graph, create_graph, inputs=inputs
#     632 )
#
# ...
